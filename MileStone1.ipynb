# %% [markdown]
# # Time Series Forecasting for Energy Use
#
# This project is selected to explore the use of basic time series forecasting techniques. The goal is not 100% accuracy but rather 95% for planning purposes. We will further refine the accuracy metrics.
#
# First, we read in the datasets for energy usage and temperature data.

# %%
import pandas as pd
import datetime as dt

# %%
#reading in csv file, using the function parse_dates to autoconvert strings to 'datetime64[ns]'
temp_df = pd.read_csv('Milestone 1 Dataset\hr_temp_20170201-20200131_subset.csv',parse_dates = ['DATE'])

# %%
temp_df
# Out:
#            STATION                DATE REPORT_TYPE  SOURCE  \
# 0      72520514762 2017-02-01 00:53:00       FM-15       7
# 1      72520514762 2017-02-01 01:53:00       FM-15       7
# 2      72520514762 2017-02-01 02:53:00       FM-15       7
# 3      72520514762 2017-02-01 03:53:00       FM-15       7
# 4      72520514762 2017-02-01 04:53:00       FM-15       7
# ...            ...                 ...         ...     ...
# 26275  72520514762 2020-01-31 19:53:00       FM-15       7
# 26276  72520514762 2020-01-31 20:53:00       FM-15       7
# 26277  72520514762 2020-01-31 21:53:00       FM-15       7
# 26278  72520514762 2020-01-31 22:53:00       FM-15       7
# 26279  72520514762 2020-01-31 23:53:00       FM-15       7
#
#        HourlyDryBulbTemperature
# 0                          37.0
# 1                          37.0
# 2                          36.0
# 3                          36.0
# 4                          36.0
# ...                         ...
# 26275                      34.0
# 26276                      33.0
# 26277                      33.0
# 26278                      33.0
# 26279                      34.0
#
# [26280 rows x 5 columns]

# %%
temp_df.dtypes
# Out:
# STATION                              int64
# DATE                        datetime64[ns]
# REPORT_TYPE                         object
# SOURCE                               int64
# HourlyDryBulbTemperature           float64
# dtype: object

# %%
#read in the megawatt usage data
load_df = pd.read_csv('Milestone 1 Dataset\hrl_load_metered - 20170201-20200131.csv ',parse_dates = ['datetime_beginning_ept'])
load_df
# Out:
#       datetime_beginning_utc datetime_beginning_ept nerc_region mkt_region  \
# 0              2/1/2017 5:00    2017-02-01 00:00:00         RFC       WEST
# 1              2/1/2017 6:00    2017-02-01 01:00:00         RFC       WEST
# 2              2/1/2017 7:00    2017-02-01 02:00:00         RFC       WEST
# 3              2/1/2017 8:00    2017-02-01 03:00:00         RFC       WEST
# 4              2/1/2017 9:00    2017-02-01 04:00:00         RFC       WEST
# ...                      ...                    ...         ...        ...
# 26275          2/1/2020 0:00    2020-01-31 19:00:00         RFC       WEST
# 26276          2/1/2020 1:00    2020-01-31 20:00:00         RFC       WEST
# 26277          2/1/2020 2:00    2020-01-31 21:00:00         RFC       WEST
# 26278          2/1/2020 3:00    2020-01-31 22:00:00         RFC       WEST
# 26279          2/1/2020 4:00    2020-01-31 23:00:00         RFC       WEST
#
#       zone load_area        mw  is_verified
# 0      DUQ       DUQ  1419.881         True
# 1      DUQ       DUQ  1379.505         True
# 2      DUQ       DUQ  1366.106         True
# 3      DUQ       DUQ  1364.453         True
# 4      DUQ       DUQ  1391.265         True
# ...    ...       ...       ...          ...
# 26275  DUQ       DUQ  1618.484         True
# 26276  DUQ       DUQ  1580.925         True
# 26277  DUQ       DUQ  1545.354         True
# 26278  DUQ       DUQ  1478.832         True
# 26279  DUQ       DUQ  1405.188         True
#
# [26280 rows x 8 columns]

# %%
load_df.dtypes
# Out:
# datetime_beginning_utc            object
# datetime_beginning_ept    datetime64[ns]
# nerc_region                       object
# mkt_region                        object
# zone                              object
# load_area                         object
# mw                               float64
# is_verified                         bool
# dtype: object

# %% [markdown]
# ## 1. Load the energy and temperature datasets into a single pandas DataFrame that is matched by date.

# %%
#date in the temp_df seems to have been shifted by 53mins forward
#We can use offset to move this back, or just round down
#confirm this using pandas

temp_df['DATE'].dt.minute.unique()
# Out:
# array([53, 49, 48, 51, 50, 52], dtype=int64)

# %%
#since the mins are not uniformly shifted, we must rounddown.
#rounddown to have the same data across the two datasets

temp_df['DATE'] = temp_df['DATE'].dt.floor('h')

# %%
#perform a left join between wattage data and temp data
combined_df = load_df.merge (temp_df, how = 'left', left_on ='datetime_beginning_ept', right_on = 'DATE')
combined_df
# Out:
#       datetime_beginning_utc datetime_beginning_ept nerc_region mkt_region  \
# 0              2/1/2017 5:00    2017-02-01 00:00:00         RFC       WEST
# 1              2/1/2017 6:00    2017-02-01 01:00:00         RFC       WEST
# 2              2/1/2017 7:00    2017-02-01 02:00:00         RFC       WEST
# 3              2/1/2017 8:00    2017-02-01 03:00:00         RFC       WEST
# 4              2/1/2017 9:00    2017-02-01 04:00:00         RFC       WEST
# ...                      ...                    ...         ...        ...
# 26275          2/1/2020 0:00    2020-01-31 19:00:00         RFC       WEST
# 26276          2/1/2020 1:00    2020-01-31 20:00:00         RFC       WEST
# 26277          2/1/2020 2:00    2020-01-31 21:00:00         RFC       WEST
# 26278          2/1/2020 3:00    2020-01-31 22:00:00         RFC       WEST
# 26279          2/1/2020 4:00    2020-01-31 23:00:00         RFC       WEST
#
#       zone load_area        mw  is_verified      STATION                DATE  \
# 0      DUQ       DUQ  1419.881         True  72520514762 2017-02-01 00:00:00
# 1      DUQ       DUQ  1379.505         True  72520514762 2017-02-01 01:00:00
# 2      DUQ       DUQ  1366.106         True  72520514762 2017-02-01 02:00:00
# 3      DUQ       DUQ  1364.453         True  72520514762 2017-02-01 03:00:00
# 4      DUQ       DUQ  1391.265         True  72520514762 2017-02-01 04:00:00
# ...    ...       ...       ...          ...          ...                 ...
# 26275  DUQ       DUQ  1618.484         True  72520514762 2020-01-31 19:00:00
# 26276  DUQ       DUQ  1580.925         True  72520514762 2020-01-31 20:00:00
# 26277  DUQ       DUQ  1545.354         True  72520514762 2020-01-31 21:00:00
# 26278  DUQ       DUQ  1478.832         True  72520514762 2020-01-31 22:00:00
# 26279  DUQ       DUQ  1405.188         True  72520514762 2020-01-31 23:00:00
#
#       REPORT_TYPE  SOURCE  HourlyDryBulbTemperature
# 0           FM-15       7                      37.0
# 1           FM-15       7                      37.0
# 2           FM-15       7                      36.0
# 3           FM-15       7                      36.0
# 4           FM-15       7                      36.0
# ...           ...     ...                       ...
# 26275       FM-15       7                      34.0
# 26276       FM-15       7                      33.0
# 26277       FM-15       7                      33.0
# 26278       FM-15       7                      33.0
# 26279       FM-15       7                      34.0
#
# [26280 rows x 13 columns]

# %%
#keep only column i care about
combined_df = combined_df[['DATE','HourlyDryBulbTemperature','mw']]
combined_df
# Out:
#                      DATE  HourlyDryBulbTemperature        mw
# 0     2017-02-01 00:00:00                      37.0  1419.881
# 1     2017-02-01 01:00:00                      37.0  1379.505
# 2     2017-02-01 02:00:00                      36.0  1366.106
# 3     2017-02-01 03:00:00                      36.0  1364.453
# 4     2017-02-01 04:00:00                      36.0  1391.265
# ...                   ...                       ...       ...
# 26275 2020-01-31 19:00:00                      34.0  1618.484
# 26276 2020-01-31 20:00:00                      33.0  1580.925
# 26277 2020-01-31 21:00:00                      33.0  1545.354
# 26278 2020-01-31 22:00:00                      33.0  1478.832
# 26279 2020-01-31 23:00:00                      34.0  1405.188
#
# [26280 rows x 3 columns]

# %% [markdown]
# # 2 Type check

# %%
#we want DATE to be datetime64 b/c we want to create more date-related fields from them
combined_df.dtypes
# Out:
# DATE                        datetime64[ns]
# HourlyDryBulbTemperature           float64
# mw                                 float64
# dtype: object

# %% [markdown]
# # 3. Create date-related variables for DEA and seasonality identification

# %%
combined_df['hour'] = combined_df['DATE'].dt.hour
combined_df['day_of_week'] = combined_df['DATE'].dt.dayofweek
combined_df['month'] = combined_df['DATE'].dt.month
combined_df['year'] = combined_df['DATE'].dt.year

# %%
combined_df
# Out:
#                      DATE  HourlyDryBulbTemperature        mw  hour  \
# 0     2017-02-01 00:00:00                      37.0  1419.881     0
# 1     2017-02-01 01:00:00                      37.0  1379.505     1
# 2     2017-02-01 02:00:00                      36.0  1366.106     2
# 3     2017-02-01 03:00:00                      36.0  1364.453     3
# 4     2017-02-01 04:00:00                      36.0  1391.265     4
# ...                   ...                       ...       ...   ...
# 26275 2020-01-31 19:00:00                      34.0  1618.484    19
# 26276 2020-01-31 20:00:00                      33.0  1580.925    20
# 26277 2020-01-31 21:00:00                      33.0  1545.354    21
# 26278 2020-01-31 22:00:00                      33.0  1478.832    22
# 26279 2020-01-31 23:00:00                      34.0  1405.188    23
#
#        day_of_week  month  year
# 0                2      2  2017
# 1                2      2  2017
# 2                2      2  2017
# 3                2      2  2017
# 4                2      2  2017
# ...            ...    ...   ...
# 26275            4      1  2020
# 26276            4      1  2020
# 26277            4      1  2020
# 26278            4      1  2020
# 26279            4      1  2020
#
# [26280 rows x 7 columns]

# %% [markdown]
# # 4. Set Index for Pandas DataFrame

# %%
combined_df.set_index('DATE')
# Out:
#                      HourlyDryBulbTemperature        mw  hour  day_of_week  \
# DATE
# 2017-02-01 00:00:00                      37.0  1419.881     0            2
# 2017-02-01 01:00:00                      37.0  1379.505     1            2
# 2017-02-01 02:00:00                      36.0  1366.106     2            2
# 2017-02-01 03:00:00                      36.0  1364.453     3            2
# 2017-02-01 04:00:00                      36.0  1391.265     4            2
# ...                                       ...       ...   ...          ...
# 2020-01-31 19:00:00                      34.0  1618.484    19            4
# 2020-01-31 20:00:00                      33.0  1580.925    20            4
# 2020-01-31 21:00:00                      33.0  1545.354    21            4
# 2020-01-31 22:00:00                      33.0  1478.832    22            4
# 2020-01-31 23:00:00                      34.0  1405.188    23            4
#
#                      month  year
# DATE
# 2017-02-01 00:00:00      2  2017
# 2017-02-01 01:00:00      2  2017
# 2017-02-01 02:00:00      2  2017
# 2017-02-01 03:00:00      2  2017
# 2017-02-01 04:00:00      2  2017
# ...                    ...   ...
# 2020-01-31 19:00:00      1  2020
# 2020-01-31 20:00:00      1  2020
# 2020-01-31 21:00:00      1  2020
# 2020-01-31 22:00:00      1  2020
# 2020-01-31 23:00:00      1  2020
#
# [26280 rows x 6 columns]

# %%
#check null values
combined_df.isnull().sum() #we see clear issues with temperature data, there are missing values
# Out:
# DATE                         0
# HourlyDryBulbTemperature    37
# mw                           0
# hour                         0
# day_of_week                  0
# month                        0
# year                         0
# dtype: int64

# %%
combined_df['HourlyDryBulbTemperature'] = combined_df['HourlyDryBulbTemperature'].interpolate(method = 'linear')

# %% [markdown]
# # 6. Splitting the dataset into train and test sets

# %%
train_df = combined_df[combined_df['DATE'] < dt.datetime(2020,1,1)]

# %%
test_df = combined_df[combined_df['DATE'] >= dt.datetime(2020,1,1)]

# %%
#checking the bottom records to make sure
train_df.tail(5)
# Out:
#                      DATE  HourlyDryBulbTemperature        mw  hour  \
# 25531 2019-12-31 19:00:00                      32.0  1606.134    19
# 25532 2019-12-31 20:00:00                      32.0  1565.014    20
# 25533 2019-12-31 21:00:00                      32.0  1515.905    21
# 25534 2019-12-31 22:00:00                      30.0  1474.519    22
# 25535 2019-12-31 23:00:00                      30.0  1421.717    23
#
#        day_of_week  month  year
# 25531            1     12  2019
# 25532            1     12  2019
# 25533            1     12  2019
# 25534            1     12  2019
# 25535            1     12  2019

# %%
test_df.tail(5)
# Out:
#                      DATE  HourlyDryBulbTemperature        mw  hour  \
# 26275 2020-01-31 19:00:00                      34.0  1618.484    19
# 26276 2020-01-31 20:00:00                      33.0  1580.925    20
# 26277 2020-01-31 21:00:00                      33.0  1545.354    21
# 26278 2020-01-31 22:00:00                      33.0  1478.832    22
# 26279 2020-01-31 23:00:00                      34.0  1405.188    23
#
#        day_of_week  month  year
# 26275            4      1  2020
# 26276            4      1  2020
# 26277            4      1  2020
# 26278            4      1  2020
# 26279            4      1  2020
